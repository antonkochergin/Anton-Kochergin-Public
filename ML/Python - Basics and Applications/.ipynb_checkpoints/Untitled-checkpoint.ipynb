# %%
def list_sum (lst):
    result = 0
    for element in lst:
        result += element
    return result

def sum(a,b):
    return a + b

y = sum(14,29)
z = list_sum([1,2,3])
print(y)
print(z)
# Out:
# 43
# 6

# %% [markdown]
# ![image.png](attachment:389deeb8-9a28-4d43-97c1-c4e1b015f36c.png)

# %%
a = []

def foo(arg1, arg2):
  a.append("foo")

foo(a.append("arg1"), a.append("arg2"))

print(a)
# Out:
# ['arg1', 'arg2', 'foo']

# %% [markdown]
# Стек

# %% [markdown]
# ![image.png](attachment:c36171f5-1a5b-4abd-ab0d-d56db3eb6f68.png)

# %% [markdown]
# Стек - "очередь" исполняемых комнанд из примера:g ждет print, f ждет g, module ждет f
